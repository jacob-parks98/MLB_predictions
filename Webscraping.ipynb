# %%
import pandas as pd
import requests 
from bs4 import BeautifulSoup as BS
from bs4 import Comment

# %% [markdown]
# # Understanding URL pattern

# %%
url = 'https://www.baseball-reference.com/leagues/majors/2021-schedule.shtml'

# %%
r = requests.get(url)

# %%
soup = BS(r.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/br/build" data-version="klecko-" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/202205101" rel="dns-prefetch"/>
# <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script async="true" type="text/javascript">
#     (function() {
# 	var host = window.location.hostname;
# 	var element = document.createElement('script');
# 	var firstScript = document.getElementsByTagName('script')[0];
# 	var url = 'https://quantcast.mgr.consensu.org'
# 	    .concat('/choice/', 'XwNYEpNeFfhfr', '/', host, '/choice.js')
# 	var uspTries = 0;
# 	var uspTriesLimit = 3;
# 	element.async = true;
# 	element.type = 'text/javascript';
# 	element.src = url;
#
# 	firstScript.parentNode.insertBefore(element, firstScript);
#
# ...

# %%
html = soup.find_all('a', text = 'Boxscore')

# %%
type(html)
# Out:
# bs4.element.ResultSet

# %%
html
# Out:
# [<a href="/boxes/ANA/ANA202104010.shtml">Boxscore</a>,
#  <a href="/boxes/CHN/CHN202104010.shtml">Boxscore</a>,
#  <a href="/boxes/CIN/CIN202104010.shtml">Boxscore</a>,
#  <a href="/boxes/COL/COL202104010.shtml">Boxscore</a>,
#  <a href="/boxes/DET/DET202104010.shtml">Boxscore</a>,
#  <a href="/boxes/KCA/KCA202104010.shtml">Boxscore</a>,
#  <a href="/boxes/MIA/MIA202104010.shtml">Boxscore</a>,
#  <a href="/boxes/MIL/MIL202104010.shtml">Boxscore</a>,
#  <a href="/boxes/NYA/NYA202104010.shtml">Boxscore</a>,
#  <a href="/boxes/OAK/OAK202104010.shtml">Boxscore</a>,
#  <a href="/boxes/PHI/PHI202104010.shtml">Boxscore</a>,
#  <a href="/boxes/SDN/SDN202104010.shtml">Boxscore</a>,
#  <a href="/boxes/SEA/SEA202104010.shtml">Boxscore</a>,
#  <a href="/boxes/ANA/ANA202104020.shtml">Boxscore</a>,
#  <a href="/boxes/BOS/BOS202104020.shtml">Boxscore</a>,
#  <a href="/boxes/COL/COL202104020.shtml">Boxscore</a>,
#  <a href="/boxes/MIA/MIA202104020.shtml">Boxscore</a>,
# ...

# %%
boxscores = [x['href'] for x in html]

# %%
boxscores
# Out:
# ['/boxes/ANA/ANA202104010.shtml',
#  '/boxes/CHN/CHN202104010.shtml',
#  '/boxes/CIN/CIN202104010.shtml',
#  '/boxes/COL/COL202104010.shtml',
#  '/boxes/DET/DET202104010.shtml',
#  '/boxes/KCA/KCA202104010.shtml',
#  '/boxes/MIA/MIA202104010.shtml',
#  '/boxes/MIL/MIL202104010.shtml',
#  '/boxes/NYA/NYA202104010.shtml',
#  '/boxes/OAK/OAK202104010.shtml',
#  '/boxes/PHI/PHI202104010.shtml',
#  '/boxes/SDN/SDN202104010.shtml',
#  '/boxes/SEA/SEA202104010.shtml',
#  '/boxes/ANA/ANA202104020.shtml',
#  '/boxes/BOS/BOS202104020.shtml',
#  '/boxes/COL/COL202104020.shtml',
#  '/boxes/MIA/MIA202104020.shtml',
#  '/boxes/OAK/OAK202104020.shtml',
#  '/boxes/SDN/SDN202104020.shtml',
#  '/boxes/SEA/SEA202104020.shtml',
#  '/boxes/ANA/ANA202104030.shtml',
#  '/boxes/BOS/BOS202104030.shtml',
#  '/boxes/CHN/CHN202104030.shtml',
#  '/boxes/CIN/CIN202104030.shtml',
#  '/boxes/COL/COL202104030.shtml',
#  '/boxes/DET/DET202104030.shtml',
#  '/boxes/KCA/KCA202104030.shtml',
# ...

# %% [markdown]
# # Finding and Testing Functions

# %%
url = 'https://www.baseball-reference.com/boxes/SEA/SEA202104180.shtml'

# %%
res = requests.get(url)

# %%
soup = BS(res.text, 'html.parser')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="no-js" data-root="/home/br/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="ie=edge" http-equiv="x-ua-compatible"/>\n  <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">\n   <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/202204011" rel="dns-prefetch"/>\n   <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\n   <script async="true" type="text/javascript">\n    (function() {\n\tvar host = window.location.hostname;\n\tvar element = document.createElement(\'script\');\n\tvar firstScript = document.getElementsByTagName(\'script\')[0];\n\tvar url = \'https://quantcast.mgr.consensu.org\'\n\t    .concat(\'/choice/\', \'XwNYEpNeFfhfr\', \'/\', host, \'/choice.js\')\n\tvar uspTries = 0;\n\tvar uspTriesLimit = 3;\n\telement.async = true;\n\telement.type = \'text/javascript\';\n\telement.src = url;\n\t\n\tfirs
# ...

# %%
soup.find_all('div', {'class':'scorebox'})
# Out:
# [<div class="scorebox">
#  <div>
#  <div itemprop="performer" itemscope="" itemtype="https://schema.org/Organization">
#  <div class="media-item logo loader">
#  <img alt="2021 Houston Astros Logo" class="teamlogo" itemscope="image" src="https://d2p3bygnnzw9w3.cloudfront.net/req/202204011/tlogo/br/HOU-2021.png"/>
#  <p><a href="http://www.sportslogos.net/">via Sports Logos.net</a></p>
#  <p><a href="https://www.sports-reference.com/blog/2016/06/redesign-team-and-league-logos-courtesy-sportslogos-net/">About logos</a></p>
#  </div>
#  <strong>
#  <a href="/teams/HOU/2021.shtml" itemprop="name">Houston Astros</a>
#  </strong>
#  </div>
#  <div class="scores">
#  <div class="score">2</div>
#  </div><div>7-8</div>
#  <div class="prevnext">
#  <a class="button2 prev" href="/boxes/SEA/SEA202104170.shtml">Prev Game</a>
#  <a class="button2 next" href="/boxes/COL/COL202104200.shtml">Next Game</a>
#  </div>
#  </div>
#  <div>
# ...

# %%
soup.find_all('a',{'itemprop':'name'})[0]['href'].split('/')
# Out:
# ['', 'teams', 'HOU', '2021.shtml']

# %%
soup.find('div', {'class':'scorebox_meta'}).findAll('div')[1].text
# Out:
# 'Start Time: 1:10 p.m. Local'

# %%
soup.findAll('div', {'class':'table_wrapper'})[2]
# Out:
# <div class="table_wrapper setup_commented commented" id="all_top_plays">
# <div class="section_heading assoc_top_plays" id="top_plays_sh">
# <span class="section_anchor" data-label="Top 5 Plays" id="top_plays_link"></span><h2>Top 5 Plays</h2> <div class="section_heading_text">
# <ul><li><a href="/about/wpa.shtml">wWE and wWPA Explanation</a></li>
# </ul>
# </div>
# </div><div class="placeholder"></div>
# <!--
#
# <div class="table_container" id="div_top_plays">
#
#     <table class="sortable stats_table min_width" id="top_plays" data-cols-to-freeze="1,2" data-toggle-class="pitch_sequence" data-toggle-text="Pitches">
#     <caption>Top 5 Plays Table</caption>
#
#
#    <colgroup><col><col><col><col><col><col><col><col><col><col><col><col></colgroup>
#    <thead>
#       <tr>
#          <th aria-label="Inn" data-stat="inning" scope="col" class=" poptip sort_default_asc show_partial_when_sorting center" data-tip="b is bottom, and t is top of the inning." >Inn</th>
# ...

# %%
if res.status_code == 200:
    s = soup.findAll('div', {'class':'table_wrapper'})

    for comment in s[0].find_all(text=lambda text: isinstance(text, Comment)):
        if comment.find("<table ") > 0:
            table = BS(comment)

# %%
rows = table.find('table').findAll('tr')

# %%
rows
# Out:
# [<tr>
#  <th aria-label="Batting" class="poptip sort_default_asc show_partial_when_sorting left" data-stat="player" data-tip="&lt;strong&gt;Player Name&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;Bold&lt;/strong&gt; can mean player is active for this team&lt;br&gt;or player has appeared in the majors&lt;br&gt;* means LHP or LHB,&lt;br&gt;# means switch hitter,&lt;br&gt;+ can mean HOFer." scope="col">Batting</th>
#  <th aria-label="At Bats" class="poptip center" data-stat="AB" data-tip="At Bats" scope="col">AB</th>
#  <th aria-label="Runs Scored" class="poptip center" data-stat="R" data-tip="Runs Scored/Allowed" scope="col">R</th>
#  <th aria-label="Hits" class="poptip center" data-stat="H" data-tip="Hits/Hits Allowed" scope="col">H</th>
#  <th aria-label="Runs Batted In" class="poptip center" data-stat="RBI" data-tip="Runs Batted In" scope="col">RBI</th>
#  <th aria-label="Bases on Balls" class="poptip center" data-stat="BB" data-tip="Bases on Balls/Walks" scope="col">BB</th>
# ...

# %%
for r in rows:
        summary = {x['data-stat']:x.text.strip() for x in r.findAll('td')}

# %%
summary
# Out:
# {'AB': '29',
#  'R': '2',
#  'H': '1',
#  'RBI': '2',
#  'BB': '2',
#  'SO': '7',
#  'PA': '34',
#  'batting_avg': '.034',
#  'onbase_perc': '.121',
#  'slugging_perc': '.069',
#  'onbase_plus_slugging': '.190',
#  'pitches': '153',
#  'strikes_total': '104',
#  'wpa_bat': '-0.128',
#  'leverage_index_avg': '0.88',
#  'wpa_bat_pos': '0.368',
#  'wpa_bat_neg': '-0.496%',
#  'cwpa_bat': '-0.09%',
#  'cli_avg': '0.99',
#  're24_bat': '-2.5',
#  'PO': '24',
#  'A': '4',
#  'details': ''}

# %%
soup.findAll('div', {'class':"section_wrapper setup_commented commented"})[1]
# Out:
# <div class="section_wrapper setup_commented commented" id="all_9662218645">
# <div class="section_heading assoc_9662218645" id="9662218645_sh">
# <span class="section_anchor" data-label="Pitching Lines and Info" id="9662218645_link"></span>
# </div><div class="placeholder"></div>
# <!--     <div class="section_content" id="div_9662218645">
#
# <div id="all_HoustonAstrospitching" class="table_wrapper">
#
# <div class="section_heading assoc_HoustonAstrospitching" id="HoustonAstrospitching_sh">
#   <span class="section_anchor" id="HoustonAstrospitching_link" data-label="Houston Astros"></span><h2>Houston Astros</h2>    <div class="section_heading_text">
#       <ul>
#       </ul>
#     </div>
#
# </div>
# <div class="table_container" id="div_HoustonAstrospitching">
#
#     <table class="sortable stats_table min_width shade_zero" id="HoustonAstrospitching" data-cols-to-freeze=",1">
#     <caption>Houston Astros Table</caption>
#
#
# ...

# %%
s = soup.findAll('div', {'class':"section_wrapper setup_commented commented"})[1]

for comment in s.find_all(text=lambda text: isinstance(text, Comment)):
    if comment.find("<table ") > 0:
        table = BS(comment)

# %%
s = soup.findAll('div', {'class':"section_wrapper setup_commented commented"})[1]
data = []
for comment in s.find_all(text=lambda text: isinstance(text, Comment)):
    if comment.find("<table ") > 0:
        table = BS(comment)
for r in table.findAll('table')[1].findAll('tr')[1:-1]:
    summary = {x['data-stat']:x.text.strip() for x in r.findAll('td')}
    summary['name'] = r.find('th',{'data-stat':'player'}).find('a')['href'].split('/')[-1][:-6].strip()
    data.append(summary)

# %%
data
# Out:
# [{'IP': '4',
#   'H': '1',
#   'R': '2',
#   'ER': '1',
#   'BB': '1',
#   'SO': '3',
#   'HR': '0',
#   'earned_run_avg': '5.40',
#   'batters_faced': '15',
#   'pitches': '78',
#   'strikes_total': '52',
#   'strikes_contact': '36',
#   'strikes_swinging': '6',
#   'strikes_looking': '10',
#   'inplay_gb_total': '4',
#   'inplay_fb_total': '7',
#   'inplay_ld': '1',
#   'inplay_unk': '0',
#   'game_score': '56',
#   'inherited_runners': '',
#   'inherited_score': '',
#   'wpa_def': '0.060',
#   'leverage_index_avg': '0.96',
#   'cwpa_def': '0.04%',
#   'cli_avg': '1.20',
#   're24_def': '0.6',
#   'name': 'margeni01'},
#  {'IP': '2',
#   'H': '0',
#   'R': '0',
#   'ER': '0',
#   'BB': '0',
#   'SO': '1',
#   'HR': '0',
#   'earned_run_avg': '3.86',
#   'batters_faced': '8',
#   'pitches': '35',
#   'strikes_total': '25',
#   'strikes_contact': '14',
#   'strikes_swinging': '3',
#   'strikes_looking': '7',
#   'inplay_gb_total': '3',
#   'inplay_fb_total': '3',
# ...

# %%
def get_game(soup, game_id):
    game = {'game_id':game_id}
    score_table = soup.find('div', {'class':'scorebox'})
    team_abbr = score_table.find_all('a',{'itemprop':'name'})
    game['away_abbr'] = team_abbr[0]['href'].split('/')[2]
    game['home_abbr'] = team_abbr[1]['href'].split('/')[2]
    date_time = soup.find('div', {'class':'scorebox_meta'}).findAll('div')
    game['date'] = date_time[0].text
    game['time'] = date_time[1].text
    return game

def batting_stats(soup,table_number):
    s = soup.findAll('div', {'class':'table_wrapper'})
    for comment in s[table_number].find_all(text=lambda text: isinstance(text, Comment)):
        if comment.find("<table ") > 0:
            table = BS(comment)
    for r in table.find('table').findAll('tr'):
        summary = {x['data-stat']:x.text.strip() for x in r.findAll('td')}
    
    return summary

def pitching_stats(soup, table_number):
    s = soup.findAll('div', {'class':"section_wrapper setup_commented commented"})[1]

    for comment in s.find_all(text=lambda text: isinstance(text, Comment)):
        if comment.find("<table ") > 0:
            table = BS(comment)
    for r in table.findAll('table')[table_number].findAll('tr'):
        summary = {x['data-stat']:x.text.strip() for x in r.findAll('td')}

    return summary

def pitchers(soup, table_number):
    s = soup.findAll('div', {'class':"section_wrapper setup_commented commented"})[1]
    data = []
    for comment in s.find_all(text=lambda text: isinstance(text, Comment)):
        if comment.find("<table ") > 0:
            table = BS(comment)
    for r in table.findAll('table')[table_number].findAll('tr')[1:-1]:
        summary = {x['data-stat']:x.text.strip() for x in r.findAll('td')}
        summary['name'] = r.find('th',{'data-stat':'player'}).find('a')['href'].split('/')[-1][:-6].strip()
        data.append(summary)
    return data

def get_all_data(url):
    res = requests.get(url)
    game_id = url.split('/')[-1][:-6]
    soup = BS(res.text,'html.parser')
    
    data = {
        'game': get_game(soup, game_id),
        'away_batting': batting_stats(soup, 0),
        'home_batting':batting_stats(soup, 1),
        'away_pitching':pitching_stats(soup, 0),
        'home_pitching':pitching_stats(soup, 1),
        'away_pitchers': pitchers(soup, 0),
        'home_pitchers': pitchers(soup, 1)
    }
    
    return data

# %%
get_all_data(url)['away_pitchers']
# Out:
# [{'IP': '4.1',
#   'H': '3',
#   'R': '4',
#   'ER': '4',
#   'BB': '3',
#   'SO': '7',
#   'HR': '0',
#   'earned_run_avg': '10.57',
#   'batters_faced': '19',
#   'pitches': '89',
#   'strikes_total': '53',
#   'strikes_contact': '30',
#   'strikes_swinging': '13',
#   'strikes_looking': '10',
#   'inplay_gb_total': '2',
#   'inplay_fb_total': '7',
#   'inplay_ld': '4',
#   'inplay_unk': '0',
#   'game_score': '45',
#   'inherited_runners': '',
#   'inherited_score': '',
#   'wpa_def': '-0.244',
#   'leverage_index_avg': '1.13',
#   'cwpa_def': '-0.17%',
#   'cli_avg': '1.28',
#   're24_def': '-1.5',
#   'name': 'odorija01'},
#  {'IP': '0.2',
#   'H': '1',
#   'R': '1',
#   'ER': '1',
#   'BB': '0',
#   'SO': '2',
#   'HR': '1',
#   'earned_run_avg': '9.00',
#   'batters_faced': '3',
#   'pitches': '12',
#   'strikes_total': '9',
#   'strikes_contact': '4',
#   'strikes_swinging': '2',
#   'strikes_looking': '3',
#   'inplay_gb_total': '0',
#   'inplay_fb_total': '1',
# ...

# %% [markdown]
# # webscraping first 10 games of 2021

# %%
boxscores[0:10]
# Out:
# ['/boxes/ANA/ANA202104010.shtml',
#  '/boxes/CHN/CHN202104010.shtml',
#  '/boxes/CIN/CIN202104010.shtml',
#  '/boxes/COL/COL202104010.shtml',
#  '/boxes/DET/DET202104010.shtml',
#  '/boxes/KCA/KCA202104010.shtml',
#  '/boxes/MIA/MIA202104010.shtml',
#  '/boxes/MIL/MIL202104010.shtml',
#  '/boxes/NYA/NYA202104010.shtml',
#  '/boxes/OAK/OAK202104010.shtml']

# %%
games = []
for link in boxscores[0:10]:
    url = 'https://www.baseball-reference.com' + link
    games.append(get_all_data(url))

# %%
games[0]
# Out:
# {'game': {'game_id': 'ANA202104010',
#   'away_abbr': 'CHW',
#   'home_abbr': 'LAA',
#   'date': 'Thursday, April 1, 2021',
#   'time': 'Start Time: 7:05 p.m. Local'},
#  'away_batting': {'AB': '33',
#   'R': '3',
#   'H': '7',
#   'RBI': '2',
#   'BB': '2',
#   'SO': '10',
#   'PA': '35',
#   'batting_avg': '.212',
#   'onbase_perc': '.257',
#   'slugging_perc': '.364',
#   'onbase_plus_slugging': '.621',
#   'pitches': '125',
#   'strikes_total': '83',
#   'wpa_bat': '-0.231',
#   'leverage_index_avg': '1.01',
#   'wpa_bat_pos': '0.525',
#   'wpa_bat_neg': '-0.756%',
#   'cwpa_bat': '-0.14%',
#   'cli_avg': '0.98',
#   're24_bat': '-1.8',
#   'PO': '24',
#   'A': '7',
#   'details': ''},
#  'home_batting': {'AB': '30',
#   'R': '4',
#   'H': '6',
#   'RBI': '4',
#   'BB': '4',
#   'SO': '10',
#   'PA': '34',
#   'batting_avg': '.200',
#   'onbase_perc': '.294',
#   'slugging_perc': '.300',
#   'onbase_plus_slugging': '.594',
#   'pitches': '140',
#   'strikes_total': '92',
# ...
